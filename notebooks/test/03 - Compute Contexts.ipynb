# %% [markdown]
# # Exercise 3 - Compute Contexts
#
# In the previous exercise, you used *datastores* and *datasets* to define shared sources of data that can be consumed in *experiments* and used to train machine learning models. In this exercise, you'll extend your experiments beyond the local compute context and take advantage of the cloud to run experiments in dynamically created compute contexts.
#
# > **Important**: This exercise assumes you have completed the previous exercises in this series - specifically, you must have:
# >
# > - Created an Azure ML Workspace.
# > - Uploaded the diabetes.csv data file to the workspace's default datastore.
# > - Registered a **Diabetes Dataset** dataset in the workspace.
#
# ## Task 1: Connect to Your Workspace
#
# The first thing you need to do is to connect to your workspace using the Azure ML SDK. Let's start by ensuring you still have the latest version installed.

# %%
#!pip install --upgrade azureml-sdk[notebooks]
import azureml.core
print("Ready to use Azure ML", azureml.core.VERSION)
# Out:
# Ready to use Azure ML 1.0.83

# %% [markdown]
# Now you're ready to connect to your workspace. When you created it in the previous exercise, you saved its configuration; so now you can simply load the workspace from its configuration file.
#
# > **Note**: If the authenticated session with your Azure subscription has expired since you completed the previous exercise, you'll be prompted to reauthenticate.

# %%
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to work with', ws.name)
# Out:
# Ready to work with contosoml

# %% [markdown]
# ## Task 2: Run an Experiment on Remote Compute
# In many cases, your local compute resources may not be sufficient to process a complex or long-running experiment that needs to process a large volume of data; and you may want to take advantage of the ability to dynamically create and use compute resources in the cloud.
#
# Azure ML supports a range of compute targets, which you can define in your workpace and use to run experiments; paying for the resources only when using them.
#
# > **Note**: In this exercise, you'll use an *Azure Machine Learning Compute* container cluster. For more details of the options for compute targets, see the [Azure ML documentation](https://docs.microsoft.com/en-us/azure/machine-learning/service/concept-compute-target).

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# Choose a name for your CPU cluster
cpu_cluster_name = "cpu-cluster"

# Verify that cluster does not exist already
try:
    cpu_cluster = ComputeTarget(workspace=ws, name=cpu_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # Create an AzureMl Compute resource (a container cluster)
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2', 
                                                           vm_priority='dedicated', 
                                                           max_nodes=4)
    cpu_cluster = ComputeTarget.create(ws, cpu_cluster_name, compute_config)

cpu_cluster.wait_for_completion(show_output=True)
# Out:
# Creating
# Succeeded
# AmlCompute wait for completion finished
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# Look at the **Compute** tab in the workspace in the [Azure portal](https://portal.azure.com) to verify that the compute resource has been created.
#
# You can also use the following code to enumerate the compute targets in your workspace.

# %%
for target_name in ws.compute_targets:
    target = ws.compute_targets[target_name]
    print(target.name, target.type)
# Out:
# cpu-cluster AmlCompute

# %%
import os
from azureml.core import Experiment

# Create an experiment
experiment_name = 'diabetes_training'
experiment = Experiment(workspace = ws, name = experiment_name)

# Create a folder for the experiment files
experiment_folder = './' + experiment_name
os.makedirs(experiment_folder, exist_ok=True)

print("Experiment:", experiment.name)
# Out:
# Experiment: diabetes_training

# %% [markdown]
# We create a separate Python script file to enable greater flexibility in terms of the Python environment, or even the compute platform, on which the experiment code is to be run; and makes it easier you to manage experiment scripts in a source-controlled environment.
# First, let's create an experiment and a local folder into which we'll put the files needed to run it.

# %%
# %%writefile $experiment_folder/diabetes_training.py
# Import libraries
import argparse
from azureml.core import Workspace, Dataset, Experiment, Run
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Set regularization parameter
parser = argparse.ArgumentParser()
parser.add_argument('--regularization', type=float, dest='reg_rate', default=0.01, help='regularization rate')
args = parser.parse_args()
reg = args.reg_rate

# Get the experiment run context
run = Run.get_context()

# load the diabetes dataset
dataset_name = 'Diabetes Dataset'
print("Loading data from " + dataset_name)
diabetes = Dataset.get_by_name(workspace=run.experiment.workspace, name=dataset_name).to_pandas_dataframe()

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a logistic regression model
print('Training a logistic regression model with regularization rate of', reg)
run.log('Regularization Rate',  np.float(reg))
model = LogisticRegression(C=1/reg, solver="liblinear").fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

os.makedirs('outputs', exist_ok=True)
# note file saved in the outputs folder is automatically uploaded into experiment record
joblib.dump(value=model, filename='outputs/diabetes_model.pkl')

run.complete()
# Out:
# Writing ./diabetes_training/diabetes_training.py

# %% [markdown]
# Now you're ready to run the experiment on the remote compute.
#
# This time, rather than the generic **Estimator** class, you'll use the **SKLearn** class, which is an estimator that is specifically designed for scikit-learn model training. You'll also specify the package dependencies in the constructor for the estimator. The only reason for this is to see that there are different ways to accomplish essentially the same task.
#
# > **Note**: Once again, this will take a while to run as the nodes in the remote compute must be started and configured before the experiment script is run.

# %%
from azureml.train.sklearn import SKLearn

# Set the script parameters
script_params = {
    '--regularization': 0.1
}


# Create a new estimator that uses the remote compute
remote_estimator = SKLearn(source_directory=experiment_folder,
                           script_params=script_params,
                           compute_target = cpu_cluster,
                           conda_packages=['pandas','ipykernel','matplotlib'],
                           pip_packages=['azureml-sdk','argparse','pyarrow'],
                           entry_script='diabetes_training.py')

# Run the experiment
run = experiment.submit(config=remote_estimator)
run.wait_for_completion(show_output=True)
# Out:
# RunId: diabetes_training_1581123592_51156155
# Web View: https://ml.azure.com/experiments/diabetes_training/runs/diabetes_training_1581123592_51156155?wsid=/subscriptions/7d48758f-d40b-4252-854c-e7d8f2ed7645/resourcegroups/contosoml_RG/workspaces/contosoml
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2020/02/08 01:00:12 Downloading source code...
# 2020/02/08 01:00:13 Finished downloading source code
# 2020/02/08 01:00:14 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/02/08 01:00:14 Successfully set up Docker network: acb_default_network
# 2020/02/08 01:00:14 Setting up Docker configuration...
# 2020/02/08 01:00:15 Successfully set up Docker configuration
# 2020/02/08 01:00:15 Logging in to registry: contosoml.azurecr.io
# 2020/02/08 01:00:16 Successfully logged into contosoml.azurecr.io
# 2020/02/08 01:00:16 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/02/08 01:00:16 Scanning for dependencies...
# 2020/02/08 01:00:17 Successfully scanned dependencies
# 2020/02/08 01:00:17 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/14 : FROM mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05: Pulling from azureml/base
# Digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#  ---> 93a72e6bd1ce
# Step 2/14 : USER root
#  ---> Running in 89d8a29dccff
# Removing intermediate container 89d8a29dccff
#  ---> c84e7cc9c479
# Step 3/14 : RUN mkdir -p $HOME/.cache
#  ---> Running in d2526c677721
# Removing intermediate container d2526c677721
#  ---> 74849a7408f0
# Step 4/14 : WORKDIR /
#  ---> Running in a6e959ef2eb7
# Removing intermediate container a6e959ef2eb7
#  ---> 1563107a6909
# Step 5/14 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> d46536697d41
# Step 6/14 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 431a74f36ea0
# Removing intermediate container 431a74f36ea0
#  ---> 446886393617
# Step 7/14 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 54ffd32a0c0e
# Step 8/14 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 948c652d90dc
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ipython_genutils-0.2 | 21 KB     |            |   0%
# ipython_genutils-0.2 | 21 KB     | ########## | 100%
#
# libpng-1.6.37        | 343 KB    |            |   0%
# libpng-1.6.37        | 343 KB    | ########## | 100%
#
# six-1.14.0           | 23 KB     |            |   0%
# six-1.14.0           | 23 KB     | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #9         |  19%
# python-3.6.2         | 27.0 MB   | ####7      |  48%
# python-3.6.2         | 27.0 MB   | #######5   |  75%
# python-3.6.2         | 27.0 MB   | #########2 |  92%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# pandas-1.0.1         | 11.1 MB   |            |   0%
# pandas-1.0.1         | 11.1 MB   | #####3     |  53%
# pandas-1.0.1         | 11.1 MB   | #######5   |  75%
# pandas-1.0.1         | 11.1 MB   | #########2 |  92%
# pandas-1.0.1         | 11.1 MB   | ########## | 100%
#
# liblapack-3.8.0      | 10 KB     |            |   0%
# liblapack-3.8.0      | 10 KB     | ########## | 100%
#
# ipython-7.12.0       | 1.1 MB    |            |   0%
# ipython-7.12.0       | 1.1 MB    | ########   |  81%
# ipython-7.12.0       | 1.1 MB    | #########8 |  98%
# ipython-7.12.0       | 1.1 MB    | ########## | 100%
#
# harfbuzz-2.4.0       | 1.5 MB    |            |   0%
# harfbuzz-2.4.0       | 1.5 MB    | ########1  |  81%
# harfbuzz-2.4.0       | 1.5 MB    | ########## | 100%
#
# pyzmq-18.1.1         | 491 KB    |            |   0%
# pyzmq-18.1.1         | 491 KB    | #########5 |  96%
# pyzmq-18.1.1         | 491 KB    | ########## | 100%
#
# xorg-libxau-1.0.9    | 13 KB     |            |   0%
# xorg-libxau-1.0.9    | 13 KB     | ########## | 100%
#
# gettext-0.19.8.1     | 3.6 MB    |            |   0%
# gettext-0.19.8.1     | 3.6 MB    | #######6   |  76%
# gettext-0.19.8.1     | 3.6 MB    | #########8 |  99%
# gettext-0.19.8.1     | 3.6 MB    | ########## | 100%
#
# tornado-6.0.3        | 636 KB    |            |   0%
# tornado-6.0.3        | 636 KB    | ########5  |  86%
# tornado-6.0.3        | 636 KB    | ########## | 100%
#
# libsodium-1.0.17     | 330 KB    |            |   0%
# libsodium-1.0.17     | 330 KB    | ########## | 100%
#
# ca-certificates-2019 | 145 KB    |            |   0%
# ca-certificates-2019 | 145 KB    | ########## | 100%
#
# xorg-libx11-1.6.9    | 918 KB    |            |   0%
# xorg-libx11-1.6.9    | 918 KB    | ########3  |  84%
# xorg-libx11-1.6.9    | 918 KB    | ########## | 100%
#
# decorator-4.4.1      | 11 KB     |            |   0%
# decorator-4.4.1      | 11 KB     | ########## | 100%
#
# xorg-libxrender-0.9. | 31 KB     |            |   0%
# xorg-libxrender-0.9. | 31 KB     | ########## | 100%
#
# xorg-xproto-7.0.31   | 72 KB     |            |   0%
# xorg-xproto-7.0.31   | 72 KB     | ########## | 100%
#
# ipykernel-5.1.4      | 160 KB    |            |   0%
# ipykernel-5.1.4      | 160 KB    | ########## | 100%
#
# sqlite-3.20.1        | 1.3 MB    |            |   0%
# sqlite-3.20.1        | 1.3 MB    | ########3  |  83%
# sqlite-3.20.1        | 1.3 MB    | ########## | 100%
#
# kiwisolver-1.1.0     | 86 KB     |            |   0%
# kiwisolver-1.1.0     | 86 KB     | ########## | 100%
#
# libstdcxx-ng-9.2.0   | 4.5 MB    |            |   0%
# libstdcxx-ng-9.2.0   | 4.5 MB    | #######8   |  78%
# libstdcxx-ng-9.2.0   | 4.5 MB    | #########8 |  98%
# libstdcxx-ng-9.2.0   | 4.5 MB    | ########## | 100%
#
# icu-64.2             | 12.6 MB   |            |   0%
# icu-64.2             | 12.6 MB   | #####1     |  52%
# icu-64.2             | 12.6 MB   | #######5   |  75%
# icu-64.2             | 12.6 MB   | #########2 |  93%
# icu-64.2             | 12.6 MB   | ########## | 100%
#
# graphite2-1.3.13     | 109 KB    |            |   0%
# graphite2-1.3.13     | 109 KB    | ########## | 100%
#
# pyqt-4.11.4          | 3.5 MB    |            |   0%
# pyqt-4.11.4          | 3.5 MB    | #######5   |  76%
# pyqt-4.11.4          | 3.5 MB    | ########9  |  89%
# pyqt-4.11.4          | 3.5 MB    | #########9 | 100%
# pyqt-4.11.4          | 3.5 MB    | ########## | 100%
#
# pytz-2019.3          | 237 KB    |            |   0%
# pytz-2019.3          | 237 KB    | #########4 |  94%
# pytz-2019.3          | 237 KB    | ########## | 100%
#
# ncurses-6.0          | 920 KB    |            |   0%
# ncurses-6.0          | 920 KB    | #######9   |  79%
# ncurses-6.0          | 920 KB    | #########4 |  94%
# ncurses-6.0          | 920 KB    | ########## | 100%
#
# python-dateutil-2.8. | 220 KB    |            |   0%
# python-dateutil-2.8. | 220 KB    | ########## | 100%
#
# certifi-2019.11.28   | 149 KB    |            |   0%
# certifi-2019.11.28   | 149 KB    | ########## | 100%
#
# libopenblas-0.3.7    | 7.6 MB    |            |   0%
# libopenblas-0.3.7    | 7.6 MB    | #######5   |  76%
# libopenblas-0.3.7    | 7.6 MB    | #########8 |  98%
# libopenblas-0.3.7    | 7.6 MB    | ########## | 100%
#
# matplotlib-3.1.3     | 7 KB      |            |   0%
# matplotlib-3.1.3     | 7 KB      | ########## | 100%
#
# matplotlib-base-3.1. | 6.6 MB    |            |   0%
# matplotlib-base-3.1. | 6.6 MB    | #######5   |  76%
# matplotlib-base-3.1. | 6.6 MB    | #########8 |  98%
# matplotlib-base-3.1. | 6.6 MB    | ########## | 100%
# libiconv-1.15        | 2.0 MB    |            |   0%
# libiconv-1.15        | 2.0 MB    | ########   |  81%
# libiconv-1.15        | 2.0 MB    | ########## | 100%
#
# jupyter_core-4.6.1   | 70 KB     |            |   0%
# jupyter_core-4.6.1   | 70 KB     | ########## | 100%
#
# openssl-1.0.2u       | 3.2 MB    |            |   0%
# openssl-1.0.2u       | 3.2 MB    | #######6   |  76%
# openssl-1.0.2u       | 3.2 MB    | #########6 |  97%
# openssl-1.0.2u       | 3.2 MB    | ########## | 100%
#
# fontconfig-2.13.1    | 340 KB    |            |   0%
# fontconfig-2.13.1    | 340 KB    | ########## | 100%
#
# pygments-2.5.2       | 669 KB    |            |   0%
# pygments-2.5.2       | 669 KB    | ########2  |  82%
# pygments-2.5.2       | 669 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | #######6   |  77%
# tk-8.6.10            | 3.2 MB    | #########7 |  98%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# libgomp-9.2.0        | 816 KB    |            |   0%
# libgomp-9.2.0        | 816 KB    | #########5 |  95%
# libgomp-9.2.0        | 816 KB    | ########## | 100%
#
# pixman-0.38.0        | 594 KB    |            |   0%
# pixman-0.38.0        | 594 KB    | #########6 |  97%
# pixman-0.38.0        | 594 KB    | ########## | 100%
#
# glib-2.58.3          | 3.3 MB    |            |   0%
# glib-2.58.3          | 3.3 MB    | #######6   |  77%
# glib-2.58.3          | 3.3 MB    | #########6 |  97%
# glib-2.58.3          | 3.3 MB    | ########## | 100%
#
# _openmp_mutex-4.5    | 435 KB    |            |   0%
# _openmp_mutex-4.5    | 435 KB    | ########## | 100%
#
# libuuid-2.32.1       | 26 KB     |            |   0%
# libuuid-2.32.1       | 26 KB     | ########## | 100%
#
# xorg-xextproto-7.3.0 | 27 KB     |            |   0%
# xorg-xextproto-7.3.0 | 27 KB     | ########## | 100%
#
# libblas-3.8.0        | 10 KB     |            |   0%
# libblas-3.8.0        | 10 KB     | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########   |  80%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# cairo-1.16.0         | 1.5 MB    |            |   0%
# cairo-1.16.0         | 1.5 MB    | ########1  |  82%
# cairo-1.16.0         | 1.5 MB    | ########## | 100%
#
# libffi-3.2.1         | 46 KB     |            |   0%
# libffi-3.2.1         | 46 KB     | ########## | 100%
#
# sip-4.18             | 263 KB    |            |   0%
# sip-4.18             | 263 KB    | ########## | 100%
#
# entrypoints-0.3      | 12 KB     |            |   0%
# entrypoints-0.3      | 12 KB     | ########## | 100%
#
# fribidi-1.0.5        | 112 KB    |            |   0%
# fribidi-1.0.5        | 112 KB    | ########## | 100%
#
# xorg-libxext-1.3.4   | 51 KB     |            |   0%
# xorg-libxext-1.3.4   | 51 KB     | ########## | 100%
#
# xorg-kbproto-1.0.7   | 26 KB     |            |   0%
# xorg-kbproto-1.0.7   | 26 KB     | ########## | 100%
#
# pyparsing-2.4.6      | 59 KB     |            |   0%
# pyparsing-2.4.6      | 59 KB     | ########## | 100%
#
# readline-7.0         | 1.1 MB    |            |   0%
# readline-7.0         | 1.1 MB    | ########5  |  85%
# readline-7.0         | 1.1 MB    | ########## | 100%
#
# jupyter_client-5.3.4 | 131 KB    |            |   0%
# jupyter_client-5.3.4 | 131 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# xorg-renderproto-0.1 | 8 KB      |            |   0%
# xorg-renderproto-0.1 | 8 KB      | ########## | 100%
#
# xz-5.2.4             | 366 KB    |            |   0%
# xz-5.2.4             | 366 KB    | #########9 |  99%
# xz-5.2.4             | 366 KB    | ########## | 100%
#
# libxcb-1.13          | 396 KB    |            |   0%
# libxcb-1.13          | 396 KB    | ########9  |  90%
# libxcb-1.13          | 396 KB    | ########## | 100%
#
# pcre-8.43            | 257 KB    |            |   0%
# pcre-8.43            | 257 KB    | ########## | 100%
#
# zeromq-4.3.2         | 668 KB    |            |   0%
# zeromq-4.3.2         | 668 KB    | ########7  |  88%
# zeromq-4.3.2         | 668 KB    | ########## | 100%
#
# zlib-1.2.11          | 105 KB    |            |   0%
# zlib-1.2.11          | 105 KB    | ########## | 100%
#
# backcall-0.1.0       | 13 KB     |            |   0%
# backcall-0.1.0       | 13 KB     | ########## | 100%
#
# freetype-2.10.0      | 884 KB    |            |   0%
# freetype-2.10.0      | 884 KB    | ########6  |  86%
# freetype-2.10.0      | 884 KB    | ########## | 100%
#
# qt-4.8.7             | 32.7 MB   |            |   0%
# qt-4.8.7             | 32.7 MB   |            |   0%
# qt-4.8.7             | 32.7 MB   | 7          |   8%
# qt-4.8.7             | 32.7 MB   | #3         |  13%
# qt-4.8.7             | 32.7 MB   | #9         |  19%
# qt-4.8.7             | 32.7 MB   | ##4        |  25%
# qt-4.8.7             | 32.7 MB   | ###        |  31%
# qt-4.8.7             | 32.7 MB   | ###5       |  36%
# qt-4.8.7             | 32.7 MB   | ####1      |  42%
# qt-4.8.7             | 32.7 MB   | ####7      |  47%
# qt-4.8.7             | 32.7 MB   | #####2     |  53%
# qt-4.8.7             | 32.7 MB   | #####8     |  58%
# qt-4.8.7             | 32.7 MB   | ######3    |  64%
# qt-4.8.7             | 32.7 MB   | ######9    |  70%
# qt-4.8.7             | 32.7 MB   | #######5   |  75%
# qt-4.8.7             | 32.7 MB   | ########   |  80%
# qt-4.8.7             | 32.7 MB   | ########4  |  84%
# qt-4.8.7             | 32.7 MB   | ########6  |  87%
# qt-4.8.7             | 32.7 MB   | ########8  |  89%
# qt-4.8.7             | 32.7 MB   | #########  |  90%
# qt-4.8.7             | 32.7 MB   | #########1 |  92%
# qt-4.8.7             | 32.7 MB   | #########2 |  93%
# qt-4.8.7             | 32.7 MB   | #########3 |  94%
# qt-4.8.7             | 32.7 MB   | #########4 |  94%
# qt-4.8.7             | 32.7 MB   | #########4 |  95%
# qt-4.8.7             | 32.7 MB   | #########5 |  95%
# qt-4.8.7             | 32.7 MB   | #########5 |  96%
# qt-4.8.7             | 32.7 MB   | #########6 |  96%
# qt-4.8.7             | 32.7 MB   | #########7 |  97%
# qt-4.8.7             | 32.7 MB   | #########7 |  98%
# qt-4.8.7             | 32.7 MB   | #########8 |  98%
# qt-4.8.7             | 32.7 MB   | #########8 |  99%
# qt-4.8.7             | 32.7 MB   | #########9 |  99%
# qt-4.8.7             | 32.7 MB   | #########9 | 100%
# qt-4.8.7             | 32.7 MB   | ########## | 100%
#
# pip-20.0.2           | 1.0 MB    |            |   0%
# pip-20.0.2           | 1.0 MB    | #######9   |  80%
# pip-20.0.2           | 1.0 MB    | #########5 |  95%
# pip-20.0.2           | 1.0 MB    | ########## | 100%
#
# traitlets-4.3.3      | 133 KB    |            |   0%
# traitlets-4.3.3      | 133 KB    | ########## | 100%
#
# jedi-0.16.0          | 770 KB    |            |   0%
# jedi-0.16.0          | 770 KB    | ########3  |  84%
# jedi-0.16.0          | 770 KB    | ########## | 100%
#
# libcblas-3.8.0       | 10 KB     |            |   0%
# libcblas-3.8.0       | 10 KB     | ########## | 100%
#
# ptyprocess-0.6.0     | 15 KB     |            |   0%
# ptyprocess-0.6.0     | 15 KB     | ########## | 100%
#
# xorg-libice-1.0.10   | 57 KB     |            |   0%
# xorg-libice-1.0.10   | 57 KB     | ########## | 100%
#
# wcwidth-0.1.8        | 19 KB     |            |   0%
# wcwidth-0.1.8        | 19 KB     | ########## | 100%
#
# xorg-libsm-1.2.3     | 25 KB     |            |   0%
# xorg-libsm-1.2.3     | 25 KB     | ########## | 100%
#
# numpy-1.18.1         | 5.2 MB    |            |   0%
# numpy-1.18.1         | 5.2 MB    | #######5   |  76%
# numpy-1.18.1         | 5.2 MB    | #########  |  91%
# numpy-1.18.1         | 5.2 MB    | ########## | 100%
#
# pickleshare-0.7.5    | 12 KB     |            |   0%
# pickleshare-0.7.5    | 12 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.7 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.7 MB    | ########1  |  82%
# libgfortran-ng-7.3.0 | 1.7 MB    | ########## | 100%
#
# libgcc-ng-9.2.0      | 8.2 MB    |            |   0%
# libgcc-ng-9.2.0      | 8.2 MB    | #######5   |  75%
# libgcc-ng-9.2.0      | 8.2 MB    | #########7 |  98%
# libgcc-ng-9.2.0      | 8.2 MB    | ########## | 100%
#
# pexpect-4.8.0        | 79 KB     |            |   0%
# pexpect-4.8.0        | 79 KB     | ########## | 100%
#
# wheel-0.34.2         | 24 KB     |            |   0%
# wheel-0.34.2         | 24 KB     | ########## | 100%
#
# xorg-libxdmcp-1.1.3  | 18 KB     |            |   0%
# xorg-libxdmcp-1.1.3  | 18 KB     | ########## | 100%
#
# prompt_toolkit-3.0.3 | 231 KB    |            |   0%
# prompt_toolkit-3.0.3 | 231 KB    | #########4 |  95%
# prompt_toolkit-3.0.3 | 231 KB    | ########## | 100%
#
# pthread-stubs-0.4    | 5 KB      |            |   0%
# pthread-stubs-0.4    | 5 KB      | ########## | 100%
#
# parso-0.6.1          | 66 KB     |            |   0%
# parso-0.6.1          | 66 KB     | ########## | 100%
#
# setuptools-45.1.0    | 642 KB    |            |   0%
# setuptools-45.1.0    | 642 KB    | ########2  |  82%
# setuptools-45.1.0    | 642 KB    | ########## | 100%
#
# cycler-0.10.0        | 9 KB      |            |   0%
# cycler-0.10.0        | 9 KB      | ########## | 100%
#
# pango-1.42.4         | 517 KB    |            |   0%
# pango-1.42.4         | 517 KB    | ########3  |  83%
# pango-1.42.4         | 517 KB    | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
# done
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.0.85-py3-none-any.whl (4.6 kB)
# Collecting argparse
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Collecting pyarrow
#   Downloading pyarrow-0.16.0-cp36-cp36m-manylinux1_x86_64.whl (62.9 MB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.0.85-py2.py3-none-any.whl (2.9 kB)
# Collecting scikit-learn==0.20.3
#   Downloading scikit_learn-0.20.3-cp36-cp36m-manylinux1_x86_64.whl (5.4 MB)
# Collecting scipy==1.2.1
#   Downloading scipy-1.2.1-cp36-cp36m-manylinux1_x86_64.whl (24.8 MB)
# Collecting numpy==1.16.2
#   Downloading numpy-1.16.2-cp36-cp36m-manylinux1_x86_64.whl (17.3 MB)
# Collecting joblib==0.13.2
#   Downloading joblib-0.13.2-py2.py3-none-any.whl (278 kB)
# Collecting azureml-train-automl-client==1.0.85.*
#   Downloading azureml_train_automl_client-1.0.85.1-py3-none-any.whl (69 kB)
# Collecting azureml-train==1.0.85.*
#   Downloading azureml_train-1.0.85-py3-none-any.whl (3.2 kB)
# Collecting azureml-dataprep[fuse]<1.2.0a,>=1.1.37a
#   Downloading azureml_dataprep-1.1.38-py3-none-any.whl (26.9 MB)
# Collecting azureml-core==1.0.85.*
#   Downloading azureml_core-1.0.85-py2.py3-none-any.whl (1.2 MB)
# Collecting azureml-pipeline==1.0.85.*
#   Downloading azureml_pipeline-1.0.85-py3-none-any.whl (3.7 kB)
# Requirement already satisfied: six>=1.0.0 in /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4/lib/python3.6/site-packages (from pyarrow->-r /azureml-environment-setup/condaenv.eq_21hhs.requirements.txt (line 3)) (1.14.0)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azureml-automl-core==1.0.85.*
#   Downloading azureml_automl_core-1.0.85.1-py3-none-any.whl (102 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4/lib/python3.6/site-packages (from azureml-train-automl-client==1.0.85.*->azureml-sdk->-r /azureml-environment-setup/condaenv.eq_21hhs.requirements.txt (line 1)) (2019.3)
# Collecting azureml-telemetry==1.0.85.*
#   Downloading azureml_telemetry-1.0.85.1-py3-none-any.whl (29 kB)
# Collecting azureml-train-core==1.0.85.*
#   Downloading azureml_train_core-1.0.85-py3-none-any.whl (8.6 MB)
# Collecting dotnetcore2>=2.1.9
#   Downloading dotnetcore2-2.1.13-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.2.2-py2.py3-none-any.whl (25 kB)
# Collecting azureml-dataprep-native<14.0.0,>=13.2.0
#   Downloading azureml_dataprep_native-13.2.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.22.0-py2.py3-none-any.whl (57 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4/lib/python3.6/site-packages (from azureml-core==1.0.85.*->azureml-sdk->-r /azureml-environment-setup/condaenv.eq_21hhs.requirements.txt (line 1)) (2.8.1)
# Collecting jsonpickle
#   Downloading jsonpickle-1.2-py2.py3-none-any.whl (32 kB)
# Collecting docker
#   Downloading docker-4.2.0-py2.py3-none-any.whl (143 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting ruamel.yaml<=0.15.89,>=0.15.35
#   Downloading ruamel.yaml-0.15.89-cp36-cp36m-manylinux1_x86_64.whl (651 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-7.1.0-py2.py3-none-any.whl (517 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-2.8-cp34-abi3-manylinux2010_x86_64.whl (2.3 MB)
# Collecting pathspec
#   Downloading pathspec-0.7.0-py2.py3-none-any.whl (25 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.2-py2.py3-none-any.whl (40 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.24-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.1.1-py2.py3-none-any.whl (117 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-8.0.1-py2.py3-none-any.whl (758 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.11-py2.py3-none-any.whl (83 kB)
# Collecting jmespath
#   Downloading jmespath-0.9.4-py2.py3-none-any.whl (24 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.2-py2.py3-none-any.whl (53 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.8-py2.py3-none-any.whl (125 kB)
# Collecting azureml-pipeline-core==1.0.85.*
#   Downloading azureml_pipeline_core-1.0.85.1-py2.py3-none-any.whl (269 kB)
# Collecting azureml-pipeline-steps==1.0.85.*
#   Downloading azureml_pipeline_steps-1.0.85-py3-none-any.whl (41 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
# Requirement already satisfied: pandas>=0.20.2 in /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.eq_21hhs.requirements.txt (line 4)) (1.0.1)
# Collecting Werkzeug>=0.14
#   Downloading Werkzeug-1.0.0-py2.py3-none-any.whl (298 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading Click-7.0-py2.py3-none-any.whl (81 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.1-py2.py3-none-any.whl (126 kB)
# Collecting azureml-train-restclients-hyperdrive==1.0.85.*
#   Downloading azureml_train_restclients_hyperdrive-1.0.85-py3-none-any.whl (18 kB)
# Collecting flake8<=3.7.9,>=3.1.0; python_version >= "3.6"
#   Downloading flake8-3.7.9-py2.py3-none-any.whl (69 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.4.0-py2.py3-none-any.whl (17 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting idna<2.9,>=2.5
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
# Collecting chardet<3.1.0,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core==1.0.85.*->azureml-sdk->-r /azureml-environment-setup/condaenv.eq_21hhs.requirements.txt (line 1)) (2019.11.28)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.2-py3-none-any.whl (21 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting pyflakes<2.2.0,>=2.1.0
#   Downloading pyflakes-2.1.1-py2.py3-none-any.whl (59 kB)
# Requirement already satisfied: entrypoints<0.4.0,>=0.3.0 in /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4/lib/python3.6/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core==1.0.85.*->azureml-train==1.0.85.*->azureml-sdk->-r /azureml-environment-setup/condaenv.eq_21hhs.requirements.txt (line 1)) (0.3)
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting pycodestyle<2.6.0,>=2.5.0
#   Downloading pycodestyle-2.5.0-py2.py3-none-any.whl (51 kB)
# Collecting pycparser
#   Downloading pycparser-2.19.tar.gz (158 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff, dill, pycparser
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=773d51f68722c3616624f1958363db27b982441c73dbddec1f41fe3a816ee6c9
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=ed01dbc0cf072e1cc50a7aa62496de369e8e58fa27acb0510b1c083a231e3695
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=c1b3324dbd6bf76e7d32df1bc571ad7f7e31000850d543be1dbed8d904ba0929
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78530 sha256=0d36bea6e5f89864c62598b2442a2aa74dd922d0e88c25d684e27d9f6f7dda13
#   Stored in directory: /root/.cache/pip/wheels/09/84/74/d2b4feb9ac9488bc83c475cb2cbe8e8b7d9cea8320d32f3787
#   Building wheel for pycparser (setup.py): started
#   Building wheel for pycparser (setup.py): finished with status 'done'
#   Created wheel for pycparser: filename=pycparser-2.19-py2.py3-none-any.whl size=111031 sha256=60769fa2a37801d9c39136ffdf77e46c53bdaaf9816a391a8117b5523c5c6fbd
#   Stored in directory: /root/.cache/pip/wheels/c6/6b/83/2608afaa57ecfb0a66ac89191a8d9bad71c62ca55ee499c2d0
# Successfully built json-logging-py fusepy liac-arff dill pycparser
# Installing collected packages: distro, dotnetcore2, cloudpickle, azureml-dataprep-native, fusepy, azureml-dataprep, azureml-automl-core, backports.weakref, backports.tempfile, pycparser, cffi, cryptography, pyopenssl, pyasn1, ndg-httpsclient, isodate, idna, urllib3, chardet, requests, oauthlib, requests-oauthlib, msrest, PyJWT, adal, msrestazure, azure-common, azure-mgmt-containerregistry, jsonpickle, websocket-client, docker, azure-graphrbac, jeepney, SecretStorage, ruamel.yaml, azure-mgmt-storage, pathspec, azure-mgmt-keyvault, contextlib2, azure-mgmt-authorization, azure-mgmt-resource, jmespath, azureml-core, applicationinsights, azureml-telemetry, azureml-train-automl-client, azureml-train-restclients-hyperdrive, pyflakes, mccabe, pycodestyle, flake8, azureml-train-core, azureml-train, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, azureml-sdk, argparse, numpy, pyarrow, liac-arff, dill, azureml-model-management-sdk, configparser, Werkzeug, itsdangerous, click, MarkupSafe, Jinja2, flask, json-logging-py, gunicorn, azureml-defaults, scipy, scikit-learn, joblib
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.1
#     Uninstalling numpy-1.18.1:
#       Successfully uninstalled numpy-1.18.1
# Successfully installed Jinja2-2.11.1 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 Werkzeug-1.0.0 adal-1.2.2 applicationinsights-0.11.9 argparse-1.4.0 azure-common-1.1.24 azure-graphrbac-0.61.1 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.1.1 azure-mgmt-resource-8.0.1 azure-mgmt-storage-7.1.0 azureml-automl-core-1.0.85.1 azureml-core-1.0.85 azureml-dataprep-1.1.38 azureml-dataprep-native-13.2.0 azureml-defaults-1.0.85 azureml-model-management-sdk-1.0.1b6.post1 azureml-pipeline-1.0.85 azureml-pipeline-core-1.0.85.1 azureml-pipeline-steps-1.0.85 azureml-sdk-1.0.85 azureml-telemetry-1.0.85.1 azureml-train-1.0.85 azureml-train-automl-client-1.0.85.1 azureml-train-core-1.0.85 azureml-train-restclients-hyperdrive-1.0.85 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.0 chardet-3.0.4 click-7.0 cloudpickle-1.2.2 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-2.8 dill-0.3.1.1 distro-1.4.0 docker-4.2.0 dotnetcore2-2.1.13 flake8-3.7.9 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.8 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.2 jmespath-0.9.4 joblib-0.13.2 json-logging-py-0.2 jsonpickle-1.2 liac-arff-2.4.0 mccabe-0.6.1 msrest-0.6.11 msrestazure-0.6.2 ndg-httpsclient-0.5.1 numpy-1.16.2 oauthlib-3.1.0 pathspec-0.7.0 pyarrow-0.16.0 pyasn1-0.4.8 pycodestyle-2.5.0 pycparser-2.19 pyflakes-2.1.1 pyopenssl-19.1.0 requests-2.22.0 requests-oauthlib-1.3.0 ruamel.yaml-0.15.89 scikit-learn-0.20.3 scipy-1.2.1 urllib3-1.25.8 websocket-client-0.57.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
# Removing intermediate container 948c652d90dc
#  ---> abc31e1920c8
# Step 9/14 : ENV PATH /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4/bin:$PATH
#  ---> Running in 308d95e591d2
# Removing intermediate container 308d95e591d2
#  ---> 6d1ea2de945d
# Step 10/14 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4
#  ---> Running in 4632cf532db5
# Removing intermediate container 4632cf532db5
#  ---> bbf88a648c05
# Step 11/14 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4/lib:$LD_LIBRARY_PATH
#  ---> Running in 8c09e5851b8f
# Removing intermediate container 8c09e5851b8f
#  ---> c36ba4d01c30
# Step 12/14 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> c52de5432e2d
# Step 13/14 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 9ac57f651d85
# Removing intermediate container 9ac57f651d85
#  ---> c9879a156102
# Step 14/14 : CMD ["bash"]
#  ---> Running in eb8881680580
# Removing intermediate container eb8881680580
#  ---> 19d15a70fe60
# Successfully built 19d15a70fe60
# Successfully tagged contosoml.azurecr.io/azureml/azureml_79a615d298dd7cdccaf71fa038da2aa2:latest
# 2020/02/08 01:04:35 Successfully executed container: acb_step_0
# 2020/02/08 01:04:35 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/02/08 01:04:35 Pushing image: contosoml.azurecr.io/azureml/azureml_79a615d298dd7cdccaf71fa038da2aa2:latest, attempt 1
# The push refers to repository [contosoml.azurecr.io/azureml/azureml_79a615d298dd7cdccaf71fa038da2aa2]
# 661f86f495bb: Preparing
# 2347f68b304c: Preparing
# 4e2ceef81fc5: Preparing
# b04ba18a2d31: Preparing
# 4ec6a9c5d33d: Preparing
# 90f72a2ec13d: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# 90f72a2ec13d: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# 4ec6a9c5d33d: Pushed
# 4e2ceef81fc5: Pushed
# 661f86f495bb: Pushed
# b04ba18a2d31: Pushed
# e1171d4d60ca: Pushed
# 90f72a2ec13d: Pushed
# 6ef1a8ae63b7: Pushed
# 340dc32eb998: Pushed
# 85389f9ead9e: Pushed
# 0e259b09e5f4: Pushed
# ccdb13a20bf2: Pushed
# 9513cdf4e497: Pushed
# 7f083f9454c0: Pushed
# f2608f66a0e3: Pushed
#
# 29f36b5893dc: Pushed
# df18b66efaa6: Pushed
# 2347f68b304c: Pushed
# latest: digest: sha256:ab2db6d231c453b9a6fc3a6d627f641d5de4b4bd38f43a3b51e274ead200a915 size: 3883
# 2020/02/08 01:06:34 Successfully pushed image: contosoml.azurecr.io/azureml/azureml_79a615d298dd7cdccaf71fa038da2aa2:latest
# 2020/02/08 01:06:34 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 259.670624)
# 2020/02/08 01:06:34 Populating digests for step ID: acb_step_0...
# 2020/02/08 01:06:36 Successfully populated digests for step ID: acb_step_0
# 2020/02/08 01:06:36 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 119.000098)
# 2020/02/08 01:06:36 The following dependencies were found:
# 2020/02/08 01:06:36
# - image:
#     registry: contosoml.azurecr.io
#     repository: azureml/azureml_79a615d298dd7cdccaf71fa038da2aa2
#     tag: latest
#     digest: sha256:ab2db6d231c453b9a6fc3a6d627f641d5de4b4bd38f43a3b51e274ead200a915
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#   git: {}
#
# Run ID: cg2 was successful after 6m25s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_79271ba3a5ffd4617e70d67878bc644091fcd0ee90ef18a890444c692f24ec3e_d.txt
# ========================================================================================================================
#
# 2020-02-08T01:12:32Z Starting output-watcher...
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_79a615d298dd7cdccaf71fa038da2aa2
# a1298f4ce990: Pulling fs layer
# 04a3282d9c4b: Pulling fs layer
# 9b0d3db6dc03: Pulling fs layer
# 8269c605f3f1: Pulling fs layer
# 6504d449e70c: Pulling fs layer
# 4e38f320d0d4: Pulling fs layer
# b0a763e8ee03: Pulling fs layer
# 11917a028ca4: Pulling fs layer
# a6c378d11cbf: Pulling fs layer
# 6cc007ad9140: Pulling fs layer
# 6c1698a608f3: Pulling fs layer
# ec6fc499aa91: Pulling fs layer
# 96154ae90d38: Pulling fs layer
# 29e72d77d02b: Pulling fs layer
# 781fcb033dd7: Pulling fs layer
# 997d732be66a: Pulling fs layer
# c7311f3b29e5: Pulling fs layer
# 8269c605f3f1: Waiting
# 6504d449e70c: Waiting
# 4e38f320d0d4: Waiting
# b0a763e8ee03: Waiting
# 11917a028ca4: Waiting
# a6c378d11cbf: Waiting
# 6cc007ad9140: Waiting
# 6c1698a608f3: Waiting
# ec6fc499aa91: Waiting
# 96154ae90d38: Waiting
# 29e72d77d02b: Waiting
# 781fcb033dd7: Waiting
# 997d732be66a: Waiting
# c7311f3b29e5: Waiting
# 9b0d3db6dc03: Verifying Checksum
# 9b0d3db6dc03: Download complete
# 04a3282d9c4b: Verifying Checksum
# 04a3282d9c4b: Download complete
# 8269c605f3f1: Verifying Checksum
# 8269c605f3f1: Download complete
# a1298f4ce990: Verifying Checksum
# a1298f4ce990: Download complete
# 4e38f320d0d4: Verifying Checksum
# 4e38f320d0d4: Download complete
# 6504d449e70c: Verifying Checksum
# 6504d449e70c: Download complete
# b0a763e8ee03: Verifying Checksum
# b0a763e8ee03: Download complete
# 11917a028ca4: Verifying Checksum
# 11917a028ca4: Download complete
# 6cc007ad9140: Verifying Checksum
# 6cc007ad9140: Download complete
# 6c1698a608f3: Verifying Checksum
# 6c1698a608f3: Download complete
# ec6fc499aa91: Verifying Checksum
# ec6fc499aa91: Download complete
# 96154ae90d38: Verifying Checksum
# 96154ae90d38: Download complete
# 29e72d77d02b: Verifying Checksum
# 29e72d77d02b: Download complete
# a6c378d11cbf: Verifying Checksum
# a6c378d11cbf: Download complete
# 781fcb033dd7: Verifying Checksum
# 781fcb033dd7: Download complete
# c7311f3b29e5: Verifying Checksum
# c7311f3b29e5: Download complete
# 997d732be66a: Verifying Checksum
# 997d732be66a: Download complete
# a1298f4ce990: Pull complete
# 04a3282d9c4b: Pull complete
# 9b0d3db6dc03: Pull complete
# 8269c605f3f1: Pull complete
# 6504d449e70c: Pull complete
# 4e38f320d0d4: Pull complete
# b0a763e8ee03: Pull complete
# 11917a028ca4: Pull complete
# a6c378d11cbf: Pull complete
# 6cc007ad9140: Pull complete
# 6c1698a608f3: Pull complete
# ec6fc499aa91: Pull complete
# 96154ae90d38: Pull complete
# 29e72d77d02b: Pull complete
# 781fcb033dd7: Pull complete
# 997d732be66a: Pull complete
# c7311f3b29e5: Pull complete
# Digest: sha256:ab2db6d231c453b9a6fc3a6d627f641d5de4b4bd38f43a3b51e274ead200a915
# Status: Downloaded newer image for contosoml.azurecr.io/azureml/azureml_79a615d298dd7cdccaf71fa038da2aa2:latest
# efd39321d3b0b8bef66b5aea90ba1af8f860193f65b74609b9a83c10585640fa
# 2020/02/08 01:14:08 Version: 3.0.01110.0001 Branch: master Commit: ab88b58d
# 2020/02/08 01:14:08 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/02/08 01:14:08 sshd runtime has already been installed in the container
# ssh-keygen: /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# ssh-keygen: /azureml-envs/azureml_9d30f259d54163aacd2c4baf19f30ff4/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
#
# Streaming azureml-logs/65_job_prep-tvmps_79271ba3a5ffd4617e70d67878bc644091fcd0ee90ef18a890444c692f24ec3e_d.txt
# ===============================================================================================================
#
# Starting job preparation. Current time:2020-02-08T01:14:15.251004
# Extracting the control code.
# Creating directory: azureml-logs/
# Retrieving project from snapshot: 8fa27047-a6ea-447a-a0d2-91785fd89ea1
# Starting the daemon thread to refresh tokens in background for process with pid = 87
# Starting project file download.
# Finished project file download.
# Download from datastores if requested.
# Download or mount from datasets if requested.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# Starting the daemon thread to refresh tokens in background for process with pid = 137
# Entering Run History Context Manager.
# Loading data from Diabetes Dataset
# Training a logistic regression model with regularization rate of 0.1
# Accuracy: 0.7893333333333333
# AUC: 0.8568632924585982
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.0011098384857177734 seconds
# Starting the daemon thread to refresh tokens in background for process with pid = 137
#
# Streaming azureml-logs/75_job_post-tvmps_79271ba3a5ffd4617e70d67878bc644091fcd0ee90ef18a890444c692f24ec3e_d.txt
# ===============================================================================================================
#
# Starting job release. Current time:2020-02-08T01:14:52.677524
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 325
# Job release is complete. Current time:2020-02-08T01:14:54.350147
#
# Execution Summary
# =================
# RunId: diabetes_training_1581123592_51156155
# Web View: https://ml.azure.com/experiments/diabetes_training/runs/diabetes_training_1581123592_51156155?wsid=/subscriptions/7d48758f-d40b-4252-854c-e7d8f2ed7645/resourcegroups/contosoml_RG/workspaces/contosoml
# {'runId': 'diabetes_training_1581123592_51156155',
#  'target': 'cpu-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2020-02-08T01:12:29.143075Z',
#  'endTimeUtc': '2020-02-08T01:15:12.061253Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'e42b9a67-8e81-4250-9a2e-0c15fbcbf44d',
#   'azureml.git.repository_uri': 'https://github.com/Sahiep/AzureMLGettingStarted',
#   'mlflow.source.git.repoURL': 'https://github.com/Sahiep/AzureMLGettingStarted',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': '9449b28c8526aae14250b181eeeb12728cdcc838',
#   'mlflow.source.git.commit': '9449b28c8526aae14250b181eeeb12728cdcc838',
#   'azureml.git.dirty': 'True',
#   'AzureML.DerivedImageName': 'azureml/azureml_79a615d298dd7cdccaf71fa038da2aa2',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': 'edf7c34e-47c8-4773-9bfb-f657ee746b9b'}, 'consumptionDetails': {'type': 'Reference'}}],
#  'runDefinition': {'script': 'diabetes_training.py',
#   'useAbsolutePath': False,
#   'arguments': ['--regularization', '0.1'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'cpu-cluster',
#   'dataReferences': {},
#   'data': {},
#   'jobName': None,
#   'maxRunDurationSeconds': None,
#   'nodeCount': 1,
#   'environment': {'name': 'Experiment diabetes_training Environment',
#    'version': 'Autosave_2020-02-08T00:59:55Z_6c1b6769',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-sdk',
#         'argparse',
#         'pyarrow',
#         'azureml-defaults',
#         'scikit-learn==0.20.3',
#         'scipy==1.2.1',
#         'numpy==1.16.2',
#         'joblib==0.13.2']},
#       'pandas',
#       'ipykernel',
#       'matplotlib'],
#      'name': 'azureml_9d30f259d54163aacd2c4baf19f30ff4'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04',
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': False},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': 1},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []}},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://contosoml.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_training_1581123592_51156155/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=Nb6U9SNeWWewgLmsmD%2FjWPWK3cH7ZwGOxhisJ2MfAoo%3D&st=2020-02-08T01%3A05%3A14Z&se=2020-02-08T09%3A15%3A14Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_79271ba3a5ffd4617e70d67878bc644091fcd0ee90ef18a890444c692f24ec3e_d.txt': 'https://contosoml.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_training_1581123592_51156155/azureml-logs/55_azureml-execution-tvmps_79271ba3a5ffd4617e70d67878bc644091fcd0ee90ef18a890444c692f24ec3e_d.txt?sv=2019-02-02&sr=b&sig=zFih6%2BrQyjIp23rgzFhflaiE%2BCK1k3ymxb0fvXuaYgw%3D&st=2020-02-08T01%3A05%3A14Z&se=2020-02-08T09%3A15%3A14Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_79271ba3a5ffd4617e70d67878bc644091fcd0ee90ef18a890444c692f24ec3e_d.txt': 'https://contosoml.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_training_1581123592_51156155/azureml-logs/65_job_prep-tvmps_79271ba3a5ffd4617e70d67878bc644091fcd0ee90ef18a890444c692f24ec3e_d.txt?sv=2019-02-02&sr=b&sig=5d4XiGsWOogVStSPn4FhNdgLesR%2BNIsF1GnZF615Zgs%3D&st=2020-02-08T01%3A05%3A14Z&se=2020-02-08T09%3A15%3A14Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://contosoml.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_training_1581123592_51156155/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=34%2B6uYlt%2FFaCwmV17bEEHe47x0u5U4g75pMMhSh50sU%3D&st=2020-02-08T01%3A05%3A14Z&se=2020-02-08T09%3A15%3A14Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_79271ba3a5ffd4617e70d67878bc644091fcd0ee90ef18a890444c692f24ec3e_d.txt': 'https://contosoml.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_training_1581123592_51156155/azureml-logs/75_job_post-tvmps_79271ba3a5ffd4617e70d67878bc644091fcd0ee90ef18a890444c692f24ec3e_d.txt?sv=2019-02-02&sr=b&sig=ts59yChYauD%2Bvpqtd%2BCzy%2BEC2UNN%2BkVKx68leg8Dx9o%3D&st=2020-02-08T01%3A05%3A14Z&se=2020-02-08T09%3A15%3A14Z&sp=r',
#   'azureml-logs/process_info.json': 'https://contosoml.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_training_1581123592_51156155/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=fAxsJmI9R81Bb%2Fhk6LTd%2BTHuE2cvrdQv3mN9XPNdWGM%3D&st=2020-02-08T01%3A05%3A14Z&se=2020-02-08T09%3A15%3A14Z&sp=r',
#   'azureml-logs/process_status.json': 'https://contosoml.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_training_1581123592_51156155/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=6q9jnQDFMCVJN1%2BEkHUKQWoj9VoR2MiMbMlMeaoL0X4%3D&st=2020-02-08T01%3A05%3A14Z&se=2020-02-08T09%3A15%3A14Z&sp=r',
#   'logs/azureml/137_azureml.log': 'https://contosoml.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_training_1581123592_51156155/logs/azureml/137_azureml.log?sv=2019-02-02&sr=b&sig=7nVgt2vapvCFQs74B2kgyzF32lWZdB6UBZkK1zOZwMc%3D&st=2020-02-08T01%3A05%3A14Z&se=2020-02-08T09%3A15%3A14Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://contosoml.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_training_1581123592_51156155/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=Hq6Sh6BEqQot1qKwTIJ5y6hhFQMnU%2B169qGLeYmLqf8%3D&st=2020-02-08T01%3A05%3A14Z&se=2020-02-08T09%3A15%3A14Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://contosoml.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_training_1581123592_51156155/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=Tya2fXAIXXUur8W3upx5wbjkT5bJGYdV6io2WNIwj5k%3D&st=2020-02-08T01%3A05%3A14Z&se=2020-02-08T09%3A15%3A14Z&sp=r'}}

# %%
run
# Out:
# Run(Experiment: diabetes_training,
# Id: diabetes_training_1581123592_51156155,
# Type: azureml.scriptrun,
# Status: Completed)

# %% [markdown]
# Now let's register the new version of the model.

# %%
from azureml.core import Model

# Register model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model', tags={'Training context':'remote compute'}, properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

# List registered models
for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 1
# 	 Training context : remote compute
# 	 AUC : 0.8568632924585982
# 	 Accuracy : 0.7893333333333333

# %% [markdown]
# So far, you've trained the model using a variety of compute options, but always using the same basic algorithm and parameters. As a result, the performance of the model has remained fairly consistent no matter how you've run the training script - and it's not really all that good!
#
# Now that you've seen how to control compute options for a model training experiment, it's time to see how you can leverage the compute scalability of the cloud to experiment with different algorithms and parameters in order to find the best possible model for your data.
